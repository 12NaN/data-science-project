# %% [markdown]
# # Project Demo
#
# This demo is designed to provide some general tips and tricks for the ITDS Fall 2019 project. For full details on the project, please refer to [the project requirements](https://grantmlong.com/teaching/fall2019/project/Project-ITDS-Fall-2019.pdf).
#
# ***
# This demo uses `scikit-learn`, but by no means are you required to use this or any other particular package.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor


# %matplotlib inline

# %%
train_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_train.csv', index_col=0)
test_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test1.csv', index_col=0)
submit1_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test2.csv', index_col=0)
submit2_df = pd.read_csv('https://grantmlong.com/data/SE_rents2018_test3.csv', index_col=0)

# %%
train_df.sample(10).transpose()
# Out:
# rental_id                                                         7325284  \
# addr_unit                                                             #4A
# building_id                                                        359569
# bedrooms                                                                2
# bathrooms                                                               1
# size_sqft                                                            1299
# created_at                                            2018-07-02 13:12:25
# addr_street                                          305 MC GUINNESS BLVD
# addr_city                                                        Brooklyn
# addr_zip                                                            11222
# addr_lat                                                          40.7329
# addr_lon                                                         -73.9524
# bin                                                           3.06434e+06
# bbl                                                            3025330033
# floor_count                                                             5
# year_built                                                           2005
# min_to_subway                                                      3.3167
# has_doorman                                                             0
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 1
# allows_pets                                                             1
# has_washer_dryer                                                        1
# has_garage                                                              1
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 4200
# no_fee                                                                  1
# description             Lofts 305s massive low-emissivity windows illu...
# neighborhood                                                   Greenpoint
# borough                                                          Brooklyn
# unit                                                                   4A
# floornumber                                                             4
# line                                                                    A
#
# rental_id                                                         7341163  \
# addr_unit                                                             #5B
# building_id                                                         18490
# bedrooms                                                                2
# bathrooms                                                               2
# size_sqft                                                             900
# created_at                                            2018-07-06 19:09:12
# addr_street                                            229 EAST 13 STREET
# addr_city                                                        New York
# addr_zip                                                            10003
# addr_lat                                                          40.7324
# addr_lon                                                         -73.9865
# bin                                                           1.08821e+06
# bbl                                                            1004690049
# floor_count                                                             8
# year_built                                                           2008
# min_to_subway                                                      1.1833
# has_doorman                                                             0
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        1
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 4395
# no_fee                                                                  0
# description             True 2 bedroom 2 baths with washer/dryer in a ...
# neighborhood                                                 East Village
# borough                                                         Manhattan
# unit                                                                   5B
# floornumber                                                             5
# line                                                                    B
#
# rental_id                                                         7261414  \
# addr_unit                                                             #9C
# building_id                                                        662614
# bedrooms                                                                1
# bathrooms                                                               1
# size_sqft                                                             650
# created_at                                            2018-06-11 14:48:40
# addr_street                                                 8709 5 AVENUE
# addr_city                                                        Brooklyn
# addr_zip                                                            11209
# addr_lat                                                          40.6205
# addr_lon                                                         -74.0267
# bin                                                           3.15377e+06
# bbl                                                            3060510005
# floor_count                                                             3
# year_built                                                           1925
# min_to_subway                                                      2.8333
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          0
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 1475
# no_fee                                                                  0
# description             1st floor 87th and 5th ave\r\nrent $1,475\r\nh...
# neighborhood                                                    Bay Ridge
# borough                                                          Brooklyn
# unit                                                                   9C
# floornumber                                                           NaN
# line                                                                  NaN
#
# rental_id                                                         7408405  \
# addr_unit                                                           #1025
# building_id                                                       1225675
# bedrooms                                                                2
# bathrooms                                                               2
# size_sqft                                                            1250
# created_at                                            2018-07-25 17:10:29
# addr_street                                        2600 NETHERLAND AVENUE
# addr_city                                                           Bronx
# addr_zip                                                            10463
# addr_lat                                                          40.8787
# addr_lon                                                         -73.9147
# bin                                                           2.08325e+06
# bbl                                                            2057220475
# floor_count                                                            30
# year_built                                                           1975
# min_to_subway                                                      5.8167
# has_doorman                                                             1
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 1
# allows_pets                                                             1
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           1
# has_pool                                                                1
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 3125
# no_fee                                                                  1
# description             Large two bedroom/two bathroom apartment featu...
# neighborhood                                                    Riverdale
# borough                                                             Bronx
# unit                                                                 1025
# floornumber                                                            10
# line                                                                   25
#
# rental_id                                                         7208263  \
# addr_unit                                                             #9M
# building_id                                                         59809
# bedrooms                                                                3
# bathrooms                                                               3
# size_sqft                                                            1772
# created_at                                            2018-05-25 11:04:56
# addr_street                                           101 WEST END AVENUE
# addr_city                                                        New York
# addr_zip                                                            10069
# addr_lat                                                          40.7751
# addr_lon                                                         -73.9884
# bin                                                           1.08578e+06
# bbl                                                            1011710062
# floor_count                                                            35
# year_built                                                           1999
# min_to_subway                                                      3.3667
# has_doorman                                                             1
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 1
# allows_pets                                                             1
# has_washer_dryer                                                        1
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           1
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 9685
# no_fee                                                                  1
# description             NO BROKER FEES At 101 West End Apartments, you...
# neighborhood                                              Upper West Side
# borough                                                         Manhattan
# unit                                                                   9M
# floornumber                                                             9
# line                                                                    M
#
# rental_id                                                         7214455  \
# addr_unit                                                              #7
# building_id                                                        196804
# bedrooms                                                                2
# bathrooms                                                               1
# size_sqft                                                             800
# created_at                                            2018-05-29 11:06:28
# addr_street                                        276 PROSPECT PARK WEST
# addr_city                                                        Brooklyn
# addr_zip                                                            11215
# addr_lat                                                          40.6583
# addr_lon                                                         -73.9827
# bin                                                            3.0169e+06
# bbl                                                            3008760044
# floor_count                                                             4
# year_built                                                           1931
# min_to_subway                                                      2.1667
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          0
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2200
# no_fee                                                                  0
# description             4th floor walk-up\r\nlarge 2 bedroom with  ple...
# neighborhood                                                   Park Slope
# borough                                                          Brooklyn
# unit                                                                    7
# floornumber                                                           NaN
# line                                                                  NaN
#
# rental_id                                                         7415689  \
# addr_unit                                                           #GRDN
# building_id                                                        203530
# bedrooms                                                                2
# bathrooms                                                               1
# size_sqft                                                            1750
# created_at                                            2018-07-27 12:50:51
# addr_street                                                140 PARK PLACE
# addr_city                                                        Brooklyn
# addr_zip                                                            11217
# addr_lat                                                          40.6777
# addr_lon                                                          -73.974
# bin                                                           3.01911e+06
# bbl                                                            3009420036
# floor_count                                                             3
# year_built                                                           1899
# min_to_subway                                                      0.6667
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             1
# has_washer_dryer                                                        1
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              1
# has_childrens_playroom                                                  0
# rent                                                                 6100
# no_fee                                                                  0
# description             NOW SHOWING!! Dreaming of living in the quinte...
# neighborhood                                                   Park Slope
# borough                                                          Brooklyn
# unit                                                                 GRDN
# floornumber                                                           NaN
# line                                                                  NaN
#
# rental_id                                                         7141258  \
# addr_unit                                                             #3F
# building_id                                                        231190
# bedrooms                                                                1
# bathrooms                                                               1
# size_sqft                                                             700
# created_at                                            2018-05-03 09:12:32
# addr_street                                           257 FLATBUSH AVENUE
# addr_city                                                        Brooklyn
# addr_zip                                                            11217
# addr_lat                                                          40.6802
# addr_lon                                                         -73.9743
# bin                                                           3.02803e+06
# bbl                                                            3011430006
# floor_count                                                             4
# year_built                                                           1930
# min_to_subway                                                      1.0833
# has_doorman                                                             0
# has_elevator                                                            0
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            0
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2750
# no_fee                                                                  0
# description             Stunning Parisian style 1 bdrm steps away from...
# neighborhood                                             Prospect Heights
# borough                                                          Brooklyn
# unit                                                                   3F
# floornumber                                                             3
# line                                                                    F
#
# rental_id                                                         7324879  \
# addr_unit                                                             #B5
# building_id                                                       1297285
# bedrooms                                                                1
# bathrooms                                                               1
# size_sqft                                                             700
# created_at                                            2018-07-02 12:03:13
# addr_street                                       23-15 ASTORIA BOULEVARD
# addr_city                                                         Astoria
# addr_zip                                                            11102
# addr_lat                                                          40.7719
# addr_lon                                                         -73.9236
# bin                                                           4.61653e+06
# bbl                                                            4008720011
# floor_count                                                             7
# year_built                                                           2013
# min_to_subway                                                      5.8333
# has_doorman                                                             0
# has_elevator                                                            1
# has_fireplace                                                           0
# has_dishwasher                                                          1
# is_furnished                                                            0
# has_gym                                                                 0
# allows_pets                                                             0
# has_washer_dryer                                                        0
# has_garage                                                              0
# has_roofdeck                                                            1
# has_concierge                                                           0
# has_pool                                                                0
# has_garden                                                              0
# has_childrens_playroom                                                  0
# rent                                                                 2700
# no_fee                                                                  1
# description             NO BROKER'S FEE!\r\nGorgeous one bedroom apart...
# neighborhood                                                      Astoria
# borough                                                            Queens
# unit                                                                   B5
# floornumber                                                             5
# line                                                                    B
#
# rental_id                           7230550
# addr_unit                               #4B
# building_id                           99757
# bedrooms                                  0
# bathrooms                                 1
# size_sqft                               500
# created_at              2018-06-01 19:53:40
# addr_street                   2194 3 AVENUE
# addr_city                          New York
# addr_zip                              10035
# addr_lat                            40.8004
# addr_lon                           -73.9386
# bin                             1.05437e+06
# bbl                              1017680038
# floor_count                               5
# year_built                             1910
# min_to_subway                        2.9333
# has_doorman                               0
# has_elevator                              0
# has_fireplace                             0
# has_dishwasher                            0
# is_furnished                              0
# has_gym                                   0
# allows_pets                               0
# has_washer_dryer                          0
# has_garage                                0
# has_roofdeck                              0
# has_concierge                             0
# has_pool                                  0
# has_garden                                0
# has_childrens_playroom                    0
# rent                                   1650
# no_fee                                    0
# description                               -
# neighborhood                    East Harlem
# borough                           Manhattan
# unit                                     4B
# floornumber                               4
# line                                      B

# %% [markdown]
# #### Build training data

# %%
# extract usable features

#feature_cols = [
#    'bedrooms', 'year_built', 'bathrooms', 'min_to_subway',
#    'size_sqft', 'no_fee', 'has_doorman', 'floornumber', 'has_pool', 'has_childrens_playroom', 'allows_pets'
#]
feature_cols = [
    'bedrooms', 'year_built', 'bathrooms', 'min_to_subway'
]
train_features = train_df[feature_cols] 

# impute missing values with medians
train_features = train_features.fillna(train_features.median(), axis=0)

# construct target vector
train_target = train_df['rent']

# %% [markdown]
# #### Fit model

# %%
lreg = LinearRegression()
lreg.fit(train_features, train_target)


#rf = RandomForestRegressor(n_estimators = 1000, random_state= 42)
#rf.fit(train_features, train_target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #### Predict and Measure Using Test 1

# %%
test_features = test_df[feature_cols] 

# impute missing values with medians
test_features = test_features.fillna(train_features.median(), axis=0)

# construct predictions 
test_df['predicted'] = lreg.predict(test_features)
#test_df['predicted']=clf.predict(test_features)

mean_squared_error(test_df['rent'], test_df['predicted'])
# Out:
# 5144072.597655631

# %% [markdown]
# #### Combine Data, Predict Values for Test 2

# %%
master_df = train_df.append(test_df, sort=False)

master_features = master_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
master_target = master_df['rent']

lreg.fit(master_features, master_target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #### Create Submission File for `test2`

# %%
submit1_features = submit1_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
submit1_df['predictions'] = lreg.predict(submit1_features)
submit1_df['predictions'].to_csv('sample_submission1.csv', header=True)

submit1_df['fake_rent'] = np.ones(submit1_df['predictions'].shape) * master_target.median()
mean_squared_error(submit1_df['predictions'], submit1_df['fake_rent'])
# Out:
# 3098524.2259505177

# %% [markdown]
# #### Create Submission File for `test3`

# %%
submit2_features = submit2_df[feature_cols].fillna(master_df[feature_cols].median(), axis=0)
submit2_df['predictions'] = lreg.predict(submit2_features)
submit2_df['predictions'].to_csv('sample_submission2.csv', header=True)

submit2_df['fake_rent'] = np.ones(submit2_df['predictions'].shape) * master_target.median()
mean_squared_error(submit2_df['predictions'], submit2_df['fake_rent'])
# Out:
# 4069309.7717325995
